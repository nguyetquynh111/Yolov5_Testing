# %%
cd yolov5
# Out:
# /media/jobhopin-ai/New Volume10/quynh_work/pytorch_objectdetecttrack/yolov5

# %%
import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# fatal: cannot change to '/media/jobhopin-ai/New': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.8.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11017MiB)
# Setup complete ✅ (16 CPUs, 62.7 GB RAM, 718.8/915.3 GB disk)

# %%
# !python train.py --img 416 --batch 100 --workers 2 --epochs 120 --data official/data.yaml --weights yolov5s.pt --cache
# Out:
# train: weights=yolov5s.pt, cfg=, data=official/data.yaml, hyp=data/hyps/hyp.scratch-low.yaml, epochs=120, batch_size=100, imgsz=416, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=2, project=runs/train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, seed=0, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# github: up to date with https://github.com/ultralytics/yolov5 ✅
# fatal: cannot change to '/media/jobhopin-ai/New': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.8.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11017MiB)
#
# ...

# %%
# !python val.py --weights runs/train/exp6/weights/last.pt --data official/data.yaml --img 416 --half
# Out:
# val: data=official/data.yaml, weights=['runs/train/exp6/weights/last.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# fatal: cannot change to '/media/jobhopin-ai/New': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.8.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11017MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /media/jobhopin-ai/New Volume10/quynh_work/pytorch_objectdetecttra
#                  Class     Images  Instances          P          R      mAP50
#                    all        897       3373      0.957      0.747      0.845      0.604
#          person_riding        897        922      0.947      0.934      0.981      0.765
# ...

# %%
# !python detect.py --weights runs/train/exp6/weights/last.pt --img 1024 --conf 0.25 --source vietnam-plate-2.jpeg
# Out:
# detect: weights=['runs/train/exp6/weights/last.pt'], source=vietnam-plate-2.jpeg, data=data/coco128.yaml, imgsz=[1024, 1024], conf_thres=0.25, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs/detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False, vid_stride=1
# fatal: cannot change to '/media/jobhopin-ai/New': No such file or directory
# YOLOv5 🚀 2023-3-6 Python-3.8.10 torch-1.8.1+cu102 CUDA:0 (NVIDIA GeForce RTX 2080 Ti, 11017MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# image 1/1 /media/jobhopin-ai/New Volume10/quynh_work/pytorch_objectdetecttrack/yolov5/vietnam-plate-2.jpeg: 704x1024 (no detections), 6.8ms
# Speed: 0.4ms pre-process, 6.8ms inference, 0.2ms NMS per image at shape (1, 3, 1024, 1024)
# ...

# %%
# !pip install "paddleocr>=2.0.1" # Recommend to use version 2.0.1+
# Out:
# Looking in indexes: https://pypi.org/simple, https://pip.repos.neuron.amazonaws.com, https://pypi.ngc.nvidia.com
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 445.9/445.9 kB 2.3 MB/s eta 0:00:001.9 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.8/8.8 MB 18.3 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 306.1/306.1 kB 24.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.3/88.3 kB 59.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.3/2.3 MB 17.4 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 948.0/948.0 kB 18.8 MB/s eta 0:00:0031m23.3 MB/s eta 0:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.9/60.9 MB 10.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.4/13.4 MB 11.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# ...
